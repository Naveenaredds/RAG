# %%
from src.loader import load_documents
from src.chunker import chunk_documents
from src.embeddings import create_embeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.loader import load_documents
#       2 from src.chunker import chunk_documents
#       3 from src.embeddings import create_embeddings
#
# ModuleNotFoundError: No module named 'src.loader'

# %%
# !pip install -r requirements.txt

# %%
from src.loader import load_documents
from src.chunker import chunk_documents
from src.embeddings import create_embeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.loader import load_documents
#       2 from src.chunker import chunk_documents
#       3 from src.embeddings import create_embeddings
#
# ModuleNotFoundError: No module named 'src.loader'

# %%
import sys
import os

# %%
# Now try the imports again
from src.loader import load_documents
from src.chunker import chunk_documents
from src.embeddings import create_embeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Now try the imports again
# ----> 2 from src.loader import load_documents
#       3 from src.chunker import chunk_documents
#       4 from src.embeddings import create_embeddings
#
# ModuleNotFoundError: No module named 'src.loader'

# %%
# This forces Jupyter to look for folders in your current directory
sys.path.append(os.path.abspath('.'))

# %%
# Now try the imports again
from src.loader import load_documents
from src.chunker import chunk_documents
from src.embeddings import create_embeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Now try the imports again
# ----> 2 from src.loader import load_documents
#       3 from src.chunker import chunk_documents
#       4 from src.embeddings import create_embeddings
#
# ModuleNotFoundError: No module named 'src.loader'

# %%
import sys
import os

# 1. Add the path first
sys.path.append(os.path.abspath('.'))

from src.rag_app.loader import load_documents
from src.rag_app.chunker import chunk_documents
from src.rag_app.embeddings import create_embeddings
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 7
#       4 # 1. Add the path first
#       5 sys.path.append(os.path.abspath('.'))
# ----> 7 from src.rag_app.loader import load_documents
#       8 from src.rag_app.chunker import chunk_documents
#       9 from src.rag_app.embeddings import create_embeddings
#
# ImportError: cannot import name 'load_documents' from 'src.rag_app.loader' (C:\Users\pc\Desktop\RAG-main\RAG-main\src\rag_app\loader.py)

# %%
os.listdir('src')
# Out:
# ['.gitkeep', 'rag_app']

# %%
from src.rag_app.loader import load_documents
from src.rag_app.chunker import chunk_documents
from src.rag_app.embeddings import create_embeddings
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from src.rag_app.loader import load_documents
#       2 from src.rag_app.chunker import chunk_documents
#       3 from src.rag_app.embeddings import create_embeddings
#
# ImportError: cannot import name 'load_documents' from 'src.rag_app.loader' (C:\Users\pc\Desktop\RAG-main\RAG-main\src\rag_app\loader.py)

# %%
# !pip install -r requirements.txt

# %%
import sys
import os

# 1. Add the path first
sys.path.append(os.path.abspath('.'))

from src.rag_app.loader import load_documents
from src.rag_app.chunker import chunk_documents
from src.rag_app.embeddings import create_embeddings
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 7
#       4 # 1. Add the path first
#       5 sys.path.append(os.path.abspath('.'))
# ----> 7 from src.rag_app.loader import load_documents
#       8 from src.rag_app.chunker import chunk_documents
#       9 from src.rag_app.embeddings import create_embeddings
#
# ImportError: cannot import name 'load_documents' from 'src.rag_app.loader' (C:\Users\pc\Desktop\RAG-main\RAG-main\src\rag_app\loader.py)

# %%
with open('src/rag_app/loader.py', 'r') as f:
    for line in f:
        if line.strip().startswith('def '):
            print(line.strip())

# %%
with open('src/rag_app/loader.py', 'r') as f:
    print(f.read())

# %%
# !pip install sentence-transformers faiss-cpu numpy
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\pc\anaconda3\anaconda\lib\site-packages (5.1.2)
# Requirement already satisfied: faiss-cpu in c:\users\pc\anaconda3\anaconda\lib\site-packages (1.12.0)
# Requirement already satisfied: numpy in c:\users\pc\anaconda3\anaconda\lib\site-packages (1.26.4)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (4.50.0)
# Requirement already satisfied: tqdm in c:\users\pc\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (2.6.0+cpu)
# Requirement already satisfied: scikit-learn in c:\users\pc\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\pc\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (0.29.3)
# Requirement already satisfied: Pillow in c:\users\pc\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from sentence-transformers) (4.13.0)
# Requirement already satisfied: packaging in c:\users\pc\anaconda3\anaconda\lib\site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: filelock in c:\users\pc\anaconda3\anaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\pc\anaconda3\anaconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: networkx in c:\users\pc\anaconda3\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\pc\anaconda3\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\pc\anaconda3\anaconda\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\anaconda3\anaconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.8.3)
